# %%
pip install snowflake-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

import numpy as np

import snowflake.connector

from sqlalchemy import create_engine

# %%
conn = snowflake.connector.connect(

    user="KUMAR3006",

    password="@Jyokumar_143@",

    account="xvcevgk-xi43656",

    warehouse="SALES_WH",

    database="SALES_FORECAST_DB",

    schema="SALES_SCHEMA"

)
print("connected successfully")
# Out:
# connected successfully

# %%
cursor = conn.cursor()

cursor.execute("SELECT CURRENT_VERSION()")

print(cursor.fetchone())
# Out:
# ('10.23.103',)

# %%
query = """

SELECT *

FROM SALES_DATA

"""

df = pd.read_sql(query, conn)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_11704\1561395088.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
cursor = conn.cursor()

cursor.execute("SELECT CURRENT_DATABASE(), CURRENT_SCHEMA(), CURRENT_WAREHOUSE();")

print(cursor.fetchone())
# Out:
# ('SALES_FORECAST_DB', 'SALES_SCHEMA', 'SALES_WH')

# %%
cursor.execute("SHOW TABLES")

for table in cursor.fetchall():
    print(table)
# Out:
# (datetime.datetime(2026, 7, 6, 21, 42, 13, 768000, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'SALES_DATA', 'SALES_FORECAST_DB', 'SALES_SCHEMA', 'TABLE', '', '', 1000, 43008, 'ACCOUNTADMIN', '1', 'OFF', 'OFF', 'OFF', None, None, 'N', 'N', 'ROLE', 'N', 'N', 'N', 'N', 'N', 'N', 'OFF', 'OFF')

# %%
print(cursor.fetchone())
# Out:
# None

# %%
cursor.execute("SHOW TABLES")

tables = cursor.fetchall()

print(tables)
# Out:
# [(datetime.datetime(2026, 7, 6, 21, 42, 13, 768000, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'SALES_DATA', 'SALES_FORECAST_DB', 'SALES_SCHEMA', 'TABLE', '', '', 1000, 43008, 'ACCOUNTADMIN', '1', 'OFF', 'OFF', 'OFF', None, None, 'N', 'N', 'ROLE', 'N', 'N', 'N', 'N', 'N', 'N', 'OFF', 'OFF')]

# %%
df.head()
df.shape
# Out:
# (1000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PRODUCT_ID            1000 non-null   int64
#  1   SALE_DATE             1000 non-null   object
#  2   SALES_REP             1000 non-null   object
#  3   REGION                1000 non-null   object
#  4   SALES_AMOUNT          1000 non-null   float64
#  5   QUANTITY_SOLD         1000 non-null   int64
#  6   PRODUCT_CATEGORY      1000 non-null   object
#  7   UNIT_COST             1000 non-null   float64
#  8   UNIT_PRICE            1000 non-null   float64
#  9   CUSTOMER_TYPE         1000 non-null   object
#  10  DISCOUNT              1000 non-null   float64
#  11  PAYMENT_METHOD        1000 non-null   object
#  12  SALES_CHANNEL         1000 non-null   object
#  13  REGION_AND_SALES_REP  1000 non-null   object
# dtypes: float64(4), int64(2), object(8)
# ...

# %%
df.describe()
# Out:
#         PRODUCT_ID  SALES_AMOUNT  QUANTITY_SOLD    UNIT_COST   UNIT_PRICE  \
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean   1050.128000   5019.265230      25.355000  2475.304550  2728.440120
# std      29.573505   2846.790126      14.159006  1417.872546  1419.399839
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2550.297500      13.000000  1238.380000  1509.085000
# 50%    1051.000000   5019.300000      25.000000  2467.235000  2696.400000
# 75%    1075.000000   7507.445000      38.000000  3702.865000  3957.970000
# max    1100.000000   9989.040000      49.000000  4995.300000  5442.150000
#
#          DISCOUNT
# count  1000.00000
# mean      0.15239
# std       0.08720
# min       0.00000
# 25%       0.08000
# 50%       0.15000
# 75%       0.23000
# max       0.30000

# %%
df.isnull().sum()
# Out:
# PRODUCT_ID              0
# SALE_DATE               0
# SALES_REP               0
# REGION                  0
# SALES_AMOUNT            0
# QUANTITY_SOLD           0
# PRODUCT_CATEGORY        0
# UNIT_COST               0
# UNIT_PRICE              0
# CUSTOMER_TYPE           0
# DISCOUNT                0
# PAYMENT_METHOD          0
# SALES_CHANNEL           0
# REGION_AND_SALES_REP    0
# dtype: int64

# %%
df["SALE_DATE"] = pd.to_datetime(df["SALE_DATE"])

# %%
df.dtypes
# Out:
# PRODUCT_ID                       int64
# SALE_DATE               datetime64[ns]
# SALES_REP                       object
# REGION                          object
# SALES_AMOUNT                   float64
# QUANTITY_SOLD                    int64
# PRODUCT_CATEGORY                object
# UNIT_COST                      float64
# UNIT_PRICE                     float64
# CUSTOMER_TYPE                   object
# DISCOUNT                       float64
# PAYMENT_METHOD                  object
# SALES_CHANNEL                   object
# REGION_AND_SALES_REP            object
# dtype: object

# %%
df.to_csv("C:/Users/kumar/Downloads/cleaned_data_project.csv", index=False)

# %%
cursor.close()

conn.close()
